# %%
pip install psycopg2
# Out:
# Collecting psycopg2
#   Using cached psycopg2-2.9.9-cp39-cp39-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\hanhn\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import psycopg2
import pandas as pd

df = pd.read_csv("TMDB_movie_dataset_v11.csv")
df
# Out:
#               id                  title  vote_average  vote_count    status  \
# 0          27205              Inception         8.364       34495  Released
# 1         157336           Interstellar         8.417       32571  Released
# 2            155        The Dark Knight         8.512       30619  Released
# 3          19995                 Avatar         7.573       29815  Released
# 4          24428           The Avengers         7.710       29166  Released
# ...          ...                    ...           ...         ...       ...
# 1054446   692168            Jock Empire         0.000           0  Released
# 1054447   692169           Sex is Weird         0.000           0  Released
# 1054448   692170  Laagi Nahi Chhute Ram         0.000           0  Released
# 1054449   692171            Trepidation         0.000           0  Released
# 1054450  1306641    It Cries Too Loudly         0.000           0  Released
#
#         release_date     revenue  runtime  adult  \
# 0         2010-07-15   825532764      148  False
# 1         2014-11-05   701729206      169  False
# 2         2008-07-16  1004558444      152  False
# 3         2009-12-15  2923706026      162  False
# 4         2012-04-25  1518815515      143  False
# ...              ...         ...      ...    ...
# 1054446   1984-01-01           0       73   True
# 1054447   2019-03-08           0        6  False
# 1054448   1963-01-01           0      142  False
# 1054449   2019-03-08           0        4  False
# 1054450          NaN           0        8  False
#
#                             backdrop_path  ...         original_title  \
# 0        /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...              Inception
# 1        /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...           Interstellar
# 2        /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...        The Dark Knight
# 3        /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...                 Avatar
# 4        /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...           The Avengers
# ...                                   ...  ...                    ...
# 1054446                               NaN  ...            Jock Empire
# 1054447                               NaN  ...           Sex is Weird
# 1054448                               NaN  ...  Laagi Nahi Chhute Ram
# 1054449                               NaN  ...            Trepidation
# 1054450  /4zMY3XUiSE2l9PJOIzrnpzkObXm.jpg  ...    It Cries Too Loudly
#
#                                                   overview popularity  \
# 0        Cobb, a skilled thief who commits corporate es...     83.952
# 1        The adventures of a group of explorers who mak...    140.241
# 2        Batman raises the stakes in his war on crime. ...    130.643
# 3        In the 22nd century, a paraplegic Marine is di...     79.932
# 4        When an unexpected enemy emerges and threatens...     98.082
# ...                                                    ...        ...
# 1054446  Jockstraps and body worship are featured in Co...      0.600
# 1054447  When her well-intentioned boyfriend suggests s...      0.600
# 1054448  An educated man falls in love with a simple wo...      0.600
# 1054449  A look into the anxiety a teenage high school ...      0.600
# 1054450  Devastated and powerless as she watched the 20...      0.600
#
#                               poster_path  \
# 0        /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1        /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2        /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3        /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4         /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                   ...
# 1054446  /ztrlaNOijRCBeQGTE3Ymqu8oJAt.jpg
# 1054447                               NaN
# 1054448                               NaN
# 1054449                               NaN
# 1054450  /k1EunibVrxdCGTwlUzzBRDZiNb3.jpg
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1054446                                                NaN
# 1054447                                                NaN
# 1054448                                                NaN
# 1054449                                                NaN
# 1054450                                                NaN
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1054446                                          NaN
# 1054447                                          NaN
# 1054448                                        Drama
# 1054449                                          NaN
# 1054450                                        Drama
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1054446                  Rollo Productions, Bijou Classics
# 1054447                                                NaN
# 1054448                                                NaN
# 1054449                                                NaN
# 1054450                                   Abingdon Virtual
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1054446                  United States of America
# 1054447                                       NaN
# 1054448                                     India
# 1054449                                       NaN
# 1054450                                       NaN
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1054446                             English
# 1054447                                 NaN
# 1054448                               Hindi
# 1054449                                 NaN
# 1054450                                 NaN
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1054446                                    gay pornography
# 1054447                                                NaN
# 1054448                                                NaN
# 1054449                                                NaN
# 1054450  dance, tragedy, modern dance, experimental fil...
#
# [1054451 rows x 24 columns]

# %%
df.dtypes
# Out:
# id                        int64
# title                    object
# vote_average            float64
# vote_count                int64
# status                   object
# release_date             object
# revenue                   int64
# runtime                   int64
# adult                      bool
# backdrop_path            object
# budget                    int64
# homepage                 object
# imdb_id                  object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# poster_path              object
# tagline                  object
# genres                   object
# production_companies     object
# production_countries     object
# spoken_languages         object
# keywords                 object
# dtype: object

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:minminlun@localhost:5432/postgres')
df.to_sql('movies', engine, if_exists='replace', index=False)
# Out:
# 451
